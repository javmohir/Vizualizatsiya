# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/Vizualizatsiya/blob/main/scatterplot_tarqoqlik_grafigi_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns  # agar seaborn o'rnatilmagan bo'lsa pip install seaborn

# %% [markdown]
# VIZUALIZASIYA
# 4.4 Scatter plot - Tarqoqlik diagrammasi
# Scatter plot yordamida ma'lumotlar qanchalik tarqoq ekanin kuzatishimiz mumkin. Bu grafik ham bir nechta ustunlar orasidagi bog'liqlikni (korrelyasiya) ko'rishga xizmat qiladi.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %% [markdown]
# Kelin scatterplot() yordamida mashinalar narxi va ishlab chiqarilgan yili o'rtasida bog'liqlikni ko'ramiz.

# %% [markdown]
# Grafikdagi har bir nuqta bu - jadvaldagi price ustuni uchun har bir qatordagi qiymatlarni ko'rsatadi. Grafikdan biz quyidagi xulosani qilishimiz mumkin:
#
# Jadvaldagi aksar mashinalar 2000-yildan keyin ishlab chiqarilgan (nuqtalar zichligidan)
# Jadvalda 1 dona 1970 yilda ishlab chiqarilgan mashina bor (va u bizga kelajakda hisob-kitoblarda halaqit berishi mumkin)
# Narx va yil o'rtasida pozitiv korrelyasiya (bog'liqlik) bor, ya'ni mashinaning yili oshgan sari (qancha yangi bo'lsa) narxi ham shuncha baland ekan.
# regplot() funksiyasi yordamida bu o'sishni ham chizib ko'rsatishimiz mumkin. Lekin, keling avval 1970-yil mashinani olib tahlaymiz.

# %%
df=df[df['year']>1998]
plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x=df['year'], y=df['price'])
plt.show()

# %%
df=df[df['year']>1998]
plt.figure(figsize=(12,6))
sns.regplot(data=df, x=df['year'], y=df['price'])
plt.show()

# %%
df = df[df.year!=1970] # yili 1970 ga teng bo'lmagan qatorlarni saqlab qolamiz

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x=df['mileage'], y=df['price'])
plt.grid()
plt.show()

# %%
df = df[df.year>1995]
plt.figure(figsize=(10,6))
sns.regplot(data=df, x=df['mileage'], y=df['price'])
plt.grid()
plt.show()

# %% [markdown]
# Bu grafikda biz negativ korrelyasiyani kuzatishimiz mumkin, y'ani, kilometri oshgan sari mashina narxi tushib borayapti.
# Grafikdagi to'gri chiziq regressiya chizig'i (regression line) deb ataladi va x va y o'qlardagi qiymatlar o'rtasidagi boqliqlikni ko'rsatadi.

# %% [markdown]
# Keling grafigimizga 3-o'zgaruvchi, mashina korobkasi turini ham qo'shamiz (transmission) buning uchun hue parametridan foydalanamiz.
#
# plt.figure(figsize=(10,6))

# %%
df = df[df.year>1995]
plt.figure(figsize=(16,6))
sns.scatterplot(data=df, x=df['mileage'], y=df['price'], hue='transmission', s=50)
plt.show()

# %%
df = df[df.year>1995]
plt.figure(figsize=(16,6))
sns.scatterplot(data=df, x=df['mileage'], y=df['price'], hue='transmission',style='fuelType', s=50)
plt.grid()
plt.show()

# %%
f = df[df.year>1995]
plt.figure(figsize=(16,6))
sns.scatterplot(data=df, x=df['mileage'], y=df['price'], hue='fuelType', s=50)
plt.grid()
plt.show()

# %% [markdown]
# Scatter plotning ayan bir ko'rinishi bu Swarm plot. swarmplot yordamida yuqoridagi har bir kategoriyani (transmission) alohida swarm (to'da) ko'rinishida chiqarish mumkin.
#
# Diqqat! swarmplotda kategoriyalar soni qancha ko'p bo'lsa, funksiya shuncha uzoq vaqt ishlaydi.

# %%
sns.swarmplot(data=df, x=df['fuelType'], y=df['price'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 88.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 40.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 96.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 89.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 48.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 96.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Yuqoridagi jadvaldan ham turli xulosalar qilish mumkin:
#
# Automatic va Semi-auto mashinalar deyarli bir hil narx kategoriyada
# Manual mashinalar arzon mashinalar segmentida (30000$ gacha).
# scatterplot haqida ko'proq: https://seaborn.pydata.org/generated/seaborn.scatterplot.html
