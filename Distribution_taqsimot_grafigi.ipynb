# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/Vizualizatsiya/blob/main/Distribution_taqsimot_grafigi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns  # agar seaborn o'rnatilmagan bo'lsa pip install seaborn

# %% [markdown]
#  VIZUALIZASIYA
#  Distribution - taqsimot
# Taqsimot grafik - o'zgaruvchi (ustun)da qanday qiymatlar mavjudligi va ularning ehtimolligini ko'rsatuvchi grafik.

# %% [markdown]
# Darsimiz uchun Mercedes-Benz firmasi avtomobillari narxini jamlagan jadvalni yuklab olamiz.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df=df[df.year>2010]
df=df[df.transmission!='Other']
df=df[df.fuelType!='Other']
df
# Out:
#             model  year   price transmission  mileage fuelType  tax   mpg  \
# 1         S Class  2017   34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5        SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# ...           ...   ...     ...          ...      ...      ...  ...   ...
# 13114     C Class  2020   35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020   24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019   30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019   37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019   54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# 5             6.2
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [12952 rows x 9 columns]

# %% [markdown]
# Keling jadvaldagi narxlarning taqsimotini ko'ramiz:

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# seaborn da taqsimotlarni ko'rsatish uchun bir nechta funksiyalar mavjud.
# Yuqorida ko'rganimiz histplot shulardan biri. Shuningdek, turli taqsimotlarni jamlaydigan yagona displot funksiyasi ham bor.
#
# displot yoki histplot qay biridan foydalanish sizning o'zingizga bog'liq. Bu ikkisining fariq shundaku, histplot va biz pastroqda ko'radigan kdeplot, ecdfplot funksiyalari yordamida chizmaga ko'proq o'zgartirishlar kiritish mumkin.
#
# Batafsil: https://seaborn.pydata.org/generated/seaborn.displot.html

# %%
sns.displot(data=df, x='price', hue=df['transmission'], height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, x=df['mileage'], hue=df['transmission'], multiple='stack', height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, x=df['price'], hue=df['transmission'], multiple='stack', height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', hue=df['transmission'], col=df['transmission'], height=10, aspect=1)
plt.show()

# %%
sns.displot(data=df, x='price', kind='kde', height=5, aspect=1.5)
plt.show()

# %% [markdown]
# KDE - Kernel Density Estimation
# Qiymatlar taqsimotini baholashning yana bir usuli bu - KDE, tasodifiy qiymatlar zichligini ko'rsatuvchi grafik.
# KDE haqida to'liq ma'lumot: https://en.wikipedia.org/wiki/Kernel_density_estimation (rus tilida ham bor)
#
# KDE grafik uchun displot yoki maxsus kdeplot funksiylaridan foydalanishimiz mumkin:

# %%
sns.displot(data=df, x='price', kde=True, height=5, aspect=2)
plt.show()

# %%
sns.kdeplot(data=df, x='price', shade=True)
plt.show()
# Out:
# <ipython-input-18-0f5cdba98305>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='price', shade=True)

# %%
sns.kdeplot(data=df, x='price', hue='fuelType', shade=True)
plt.show()
# Out:
# <ipython-input-19-c5ee6d7bd9df>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='price', hue='fuelType', shade=True)

# %%
sns.displot(data=df, x='price', hue='fuelType', kind='kde', height=5, aspect=2 )
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(data=df, x='price', col='fuelType', kind='kde', height=15, aspect=1)
plt.show()

# %% [markdown]
# Ikki o'lchamli (2D) KDE

# %%
sns.displot(data=df, x='price', y='year', kind='kde', height=6, aspect=1.5)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# CDF - cumulative distribution function
# Kumulyativ taqsimot funksiyasi - berilgan qiymatning ehtimolligini ko'rsatuvchi parametr.
#
# To'liq: https://en.wikipedia.org/wiki/Cumulative_distribution_function

# %%
sns.displot(data=df, x='price', kind='ecdf', height=5, aspect=1.5)
plt.xticks(rotation=90)
plt.grid(which='both') # setka (major, minor, both) qiymatlarini berib ko'ring
plt.minorticks_on()
plt.show()

# %%
sns.displot(data=df, x='mileage', kind='ecdf', height=5, aspect=1.5)
plt.xticks(rotation=90)
plt.grid(which='both')
plt.minorticks_on()
plt.show()

# %%
sns.displot(data=df, x='price', hue='fuelType', kind='ecdf', height=5, aspect=1.5)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
sns.ecdfplot(data=df, x='price', hue=df['transmission'])
plt.grid()
plt.show()

# %% [markdown]
# displot haqida batafsil: https://seaborn.pydata.org/generated/seaborn.displot.html
